# %% [markdown]
# # 1. Library Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# # 2. Data Load

# %%
file_path = './database/'

data = pd.read_csv(file_path+'cell2celltrain.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             50891 non-null  float64
#  3   MonthlyMinutes             50891 non-null  float64
#  4   TotalRecurringCharge       50891 non-null  float64
#  5   DirectorAssistedCalls      50891 non-null  float64
#  6   OverageMinutes             50891 non-null  float64
#  7   RoamingCalls               50891 non-null  float64
#  8   PercChangeMinutes          50680 non-null  float64
#  9   PercChangeRevenues         50680 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
#  13  CustomerCareCalls          51047 non-null  float64
#  14  ThreewayCalls              51047 non-null  float64
#  15  ReceivedCalls              51047 non-null  float64
#  16  OutboundCalls              51047 non-null  float64
#  17  InboundCalls               51047 non-null  float64
#  18  PeakCallsInOut             51047 non-null  float64
#  19  OffPeakCallsInOut          51047 non-null  float64
#  20  DroppedBlockedCalls        51047 non-null  float64
#  21  CallForwardingCalls        51047 non-null  float64
#  22  CallWaitingCalls           51047 non-null  float64
#  23  MonthsInService            51047 non-null  int64
#  24  UniqueSubs                 51047 non-null  int64
#  25  ActiveSubs                 51047 non-null  int64
#  26  ServiceArea                51023 non-null  object
#  27  Handsets                   51046 non-null  float64
#  28  HandsetModels              51046 non-null  float64
#  29  CurrentEquipmentDays       51046 non-null  float64
#  30  AgeHH1                     50138 non-null  float64
#  31  AgeHH2                     50138 non-null  float64
#  32  ChildrenInHH               51047 non-null  object
#  33  HandsetRefurbished         51047 non-null  object
#  34  HandsetWebCapable          51047 non-null  object
#  35  TruckOwner                 51047 non-null  object
#  36  RVOwner                    51047 non-null  object
#  37  Homeownership              51047 non-null  object
#  38  BuysViaMailOrder           51047 non-null  object
#  39  RespondsToMailOffers       51047 non-null  object
#  40  OptOutMailings             51047 non-null  object
#  41  NonUSTravel                51047 non-null  object
#  42  OwnsComputer               51047 non-null  object
#  43  HasCreditCard              51047 non-null  object
#  44  RetentionCalls             51047 non-null  int64
#  45  RetentionOffersAccepted    51047 non-null  int64
#  46  NewCellphoneUser           51047 non-null  object
#  47  NotNewCellphoneUser        51047 non-null  object
#  48  ReferralsMadeBySubscriber  51047 non-null  int64
#  49  IncomeGroup                51047 non-null  int64
#  50  OwnsMotorcycle             51047 non-null  object
#  51  AdjustmentsToCreditRating  51047 non-null  int64
#  52  HandsetPrice               51047 non-null  object
#  53  MadeCallToRetentionTeam    51047 non-null  object
#  54  CreditRating               51047 non-null  object
#  55  PrizmCode                  51047 non-null  object
#  56  Occupation                 51047 non-null  object
#  57  MaritalStatus              51047 non-null  object
# dtypes: float64(26), int64(9), object(23)
# memory usage: 22.6+ MB

# %% [markdown]
# # 3. Data PreProcessing

# %% [markdown]
# ## 3-1. Nan Value

# %%
data.isna().sum()
# Out:
# CustomerID                     0
# Churn                          0
# MonthlyRevenue               156
# MonthlyMinutes               156
# TotalRecurringCharge         156
# DirectorAssistedCalls        156
# OverageMinutes               156
# RoamingCalls                 156
# PercChangeMinutes            367
# PercChangeRevenues           367
# DroppedCalls                   0
# BlockedCalls                   0
# UnansweredCalls                0
# CustomerCareCalls              0
# ThreewayCalls                  0
# ReceivedCalls                  0
# OutboundCalls                  0
# InboundCalls                   0
# PeakCallsInOut                 0
# OffPeakCallsInOut              0
# DroppedBlockedCalls            0
# CallForwardingCalls            0
# CallWaitingCalls               0
# MonthsInService                0
# UniqueSubs                     0
# ActiveSubs                     0
# ServiceArea                   24
# Handsets                       1
# HandsetModels                  1
# CurrentEquipmentDays           1
# AgeHH1                       909
# AgeHH2                       909
# ChildrenInHH                   0
# HandsetRefurbished             0
# HandsetWebCapable              0
# TruckOwner                     0
# RVOwner                        0
# Homeownership                  0
# BuysViaMailOrder               0
# RespondsToMailOffers           0
# OptOutMailings                 0
# NonUSTravel                    0
# OwnsComputer                   0
# HasCreditCard                  0
# RetentionCalls                 0
# RetentionOffersAccepted        0
# NewCellphoneUser               0
# NotNewCellphoneUser            0
# ReferralsMadeBySubscriber      0
# IncomeGroup                    0
# OwnsMotorcycle                 0
# AdjustmentsToCreditRating      0
# HandsetPrice                   0
# MadeCallToRetentionTeam        0
# CreditRating                   0
# PrizmCode                      0
# Occupation                     0
# MaritalStatus                  0
# dtype: int64

# %%
data = data.dropna()

# %% [markdown]
# ## 3-2. Object Feature Encoding

# %%
object_features = data.select_dtypes(['object']).columns

object_features
# Out:
# Index(['Churn', 'ServiceArea', 'ChildrenInHH', 'HandsetRefurbished',
#        'HandsetWebCapable', 'TruckOwner', 'RVOwner', 'Homeownership',
#        'BuysViaMailOrder', 'RespondsToMailOffers', 'OptOutMailings',
#        'NonUSTravel', 'OwnsComputer', 'HasCreditCard', 'NewCellphoneUser',
#        'NotNewCellphoneUser', 'OwnsMotorcycle', 'HandsetPrice',
#        'MadeCallToRetentionTeam', 'CreditRating', 'PrizmCode', 'Occupation',
#        'MaritalStatus'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for feature in object_features:
    data[feature] = encoder.fit_transform(data[feature])
    print(f"feature : {feature}")
    print(f"encoded : {encoder.classes_}")
# Out:
# feature : Churn
# encoded : ['No' 'Yes']
# feature : ServiceArea
# encoded : ['AIRAIK803' 'AIRAND864' 'AIRASH828' 'AIRAUG706' 'AIRBEA843' 'AIRCAM803'
#  'AIRCHA843' 'AIRCOL803' 'AIRELI252' 'AIRFLO843' 'AIRGAF864' 'AIRGEO843'
#  'AIRGOL919' 'AIRGRE864' 'AIRGRN252' 'AIRGWD864' 'AIRHHI843' 'AIRHIC828'
#  'AIRJAC910' 'AIRKIN252' 'AIRMAR828' 'AIRMOR828' 'AIRMYR843' 'AIRNEW803'
#  'AIRNWB252' 'AIRORA803' 'AIRROA252' 'AIRROC252' 'AIRSAV912' 'AIRSPA864'
#  'AIRSUM803' 'AIRWIL910' 'AIRWIN252' 'AIRWYV828' 'APCANN443' 'APCBAL410'
#  'APCBEL443' 'APCBET240' 'APCEAS443' 'APCFCH703' 'APCFRD301' 'APCFRE540'
#  'APCLEE703' 'APCLXT240' 'APCSAL443' 'APCSIL301' 'APCSVP443' 'APCWAL240'
#  'APCWAR540' 'APCWAS202' 'APCWES443' 'ATHHAM423' 'ATHJHC423' 'ATHKIN423'
#  'ATHLIM423' 'ATLALB912' 'ATLANE678' 'ATLATH706' 'ATLATL678' 'ATLATN423'
#  'ATLBRU912' 'ATLCHA423' 'ATLCHN706' 'ATLCOL706' 'ATLDAL334' 'ATLDBL478'
#  'ATLDOT334' 'ATLDTN706' 'ATLJCK901' 'ATLKNO423' 'ATLLAG706' 'ATLMAC912'
#  'ATLMDV478' 'ATLMEM901' 'ATLNOR678' 'ATLOPE334' 'ATLOVB601' 'ATLPRR478'
#  'ATLROS678' 'ATLSEN662' 'ATLSWT423' 'ATLTUN601' 'ATLVAL229' 'ATLWMP870'
#  'AWIAPP920' 'AWIFON920' 'AWIGRE920' 'AWIMAN920' 'AWIOSH920' 'AWISHE920'
#  'BIRBIR205' 'BIRJAS205' 'BIRPEL205' 'BOSBOS508' 'BOSBOS617' 'BOSBOS781'
#  'BOSBOS978' 'BOSBRA781' 'BOSFRA508' 'BOSHYA508' 'BOSMAN603' 'BOSNSH603'
#  'BOSPRO401' 'BOSPTL207' 'BOSWOR508' 'CHIBLO309' 'CHICHA217' 'CHICHI312'
#  'CHICHI773' 'CHICPT219' 'CHIDAV319' 'CHIDEC217' 'CHIDEK815' 'CHIGRY219'
#  'CHIJOL815' 'CHIKAN815' 'CHILAG630' 'CHILAG708' 'CHILAS815' 'CHIMTV618'
#  'CHINBK847' 'CHIPEO309' 'CHIRCK815' 'CHIROC309' 'CHISPR217' 'CHIWAT319'
#  'DALATH903' 'DALCOM903' 'DALCRS903' 'DALDAL214' 'DALDEN903' 'DALDTN940'
#  'DALFTW817' 'DALGRE903' 'DALGVL940' 'DALKAU469' 'DALMNW940' 'DALMVN903'
#  'DALSHR903' 'DALSLS903' 'DALSTV254' 'DENBOU303' 'DENCOL719' 'DENDEN303'
#  'DENDIL970' 'DENFTC970' 'DENGLD303' 'DENGRE970' 'DENVAL970' 'DETADR517'
#  'DETANN734' 'DETBAT616' 'DETBNH616' 'DETBWG419' 'DETDET313' 'DETFER248'
#  'DETFLI810' 'DETFRE419' 'DETJAC517' 'DETKAL616' 'DETLAN517' 'DETMON734'
#  'DETNOR248' 'DETPON248' 'DETROS810' 'DETSOU248' 'DETTOL419' 'DETTRO248'
#  'DETWAS419' 'DETWYN734' 'FLNARC863' 'FLNAVO863' 'FLNBAR863' 'FLNBEL352'
#  'FLNBRD941' 'FLNBSH352' 'FLNCLR813' 'FLNCOC407' 'FLNCRY352' 'FLNDAY904'
#  'FLNEUS352' 'FLNFRN904' 'FLNGAN352' 'FLNHNC863' 'FLNINV352' 'FLNJAC904'
#  'FLNKEH352' 'FLNKEN321' 'FLNKIS407' 'FLNLAK941' 'FLNLEE352' 'FLNLKC904'
#  'FLNLKP863' 'FLNLKW863' 'FLNNPR813' 'FLNOCA352' 'FLNOGC904' 'FLNORL407'
#  'FLNPAL904' 'FLNSAG904' 'FLNSAN407' 'FLNSAR941' 'FLNSEB863' 'FLNSMY904'
#  'FLNSTK904' 'FLNTAL850' 'FLNTAM813' 'FLNWIL352' 'FLNWNH941' 'FLNWNP407'
#  'FLNZEP813' 'GCWBTR225' 'GCWGUL228' 'GCWLAF337' 'HARBRI203' 'HARHAR860'
#  'HARLON860' 'HARNEW203' 'HARNOR203' 'HARSPR413' 'HARWAT203' 'HOUANG409'
#  'HOUBMT409' 'HOUBRN409' 'HOUCON409' 'HOUFRE409' 'HOUGLV409' 'HOUHOU281'
#  'HOUHUN936' 'HOULJK409' 'HOUSPR832' 'HOUVIC361' 'HWIHON808' 'HWIMAU808'
#  'INDAND765' 'INDCIC317' 'INDCLO765' 'INDCRA765' 'INDFRA765' 'INDIND317'
#  'INDLAF765' 'INDMUN765' 'INHBLU419' 'INHCEL419' 'INHCRI419' 'INHDFN419'
#  'INHFIN419' 'INHFTW219' 'INHHIC419' 'INHKOK765' 'INHSBN219' 'INHVNW419'
#  'INUEVA812' 'IPMGDR616' 'IPMHOL616' 'IPMMID517' 'IPMSAG517' 'KCYCLI660'
#  'KCYELD316' 'KCYHES316' 'KCYHNV816' 'KCYHUT316' 'KCYKCK913' 'KCYKCM816'
#  'KCYLAW913' 'KCYLEA913' 'KCYNEW316' 'KCYOTW785' 'KCYTOP913' 'KCYWAR660'
#  'KCYWIC316' 'LAUBRO601' 'LAUCLM662' 'LAUGNW662' 'LAUHAT601' 'LAUJAC601'
#  'LAUNAT601' 'LAUTUP662' 'LAWBUM409' 'LAXALA562' 'LAXALB626' 'LAXANA714'
#  'LAXBEV310' 'LAXBUR818' 'LAXCAN661' 'LAXCAS661' 'LAXCDG310' 'LAXCOR909'
#  'LAXCOV626' 'LAXCUL310' 'LAXDOW562' 'LAXIND760' 'LAXING310' 'LAXIRV949'
#  'LAXLAG949' 'LAXLAN661' 'LAXLAX213' 'LAXLAX323' 'LAXMON323' 'LAXOAK805'
#  'LAXONT909' 'LAXOXN805' 'LAXPAS626' 'LAXPER909' 'LAXPSG760' 'LAXRIV909'
#  'LAXSAN714' 'LAXSBN909' 'LAXSFN818' 'LAXSIM805' 'LAXSJC949' 'LAXSMN310'
#  'LAXSNP310' 'LAXVEN805' 'LAXVIC760' 'LAXVNY818' 'LAXWES310' 'LOUCOR812'
#  'LOUETN502' 'LOUFRK502' 'LOULEX606' 'LOULOU502' 'LOUNAL812' 'MIABON941'
#  'MIADEL561' 'MIADFD954' 'MIAFTL954' 'MIAFTM941' 'MIAHWD954' 'MIAJUP561'
#  'MIAKEY305' 'MIAMAR305' 'MIAMIA305' 'MIANAP941' 'MIANDA305' 'MIAOKE863'
#  'MIAPOR941' 'MIAPSL561' 'MIASUG305' 'MIAVER561' 'MIAWPB561' 'MILBEL608'
#  'MILBUR262' 'MILJAN608' 'MILJNC920' 'MILKEN414' 'MILLAK262' 'MILLKM920'
#  'MILMAD608' 'MILMIL414' 'MILRAC414' 'MILWAT920' 'MILWAU262' 'MINBLO952'
#  'MINCOR763' 'MINMIN612' 'MINSTP612' 'NCRALB704' 'NCRASH336' 'NCRCHA704'
#  'NCRCHE757' 'NCRCLA919' 'NCRCON704' 'NCRCRY919' 'NCRDNN910' 'NCRDUR919'
#  'NCRFAY910' 'NCRGRB757' 'NCRGRE336' 'NCRGST704' 'NCRHAR704' 'NCRHEN252'
#  'NCRHGP336' 'NCRKAN704' 'NCRLUM910' 'NCRMID704' 'NCRMIL803' 'NCRMON704'
#  'NCRNWN757' 'NCROXF919' 'NCRPIT919' 'NCRPOR757' 'NCRPTR804' 'NCRRAL919'
#  'NCRRIC804' 'NCRROC803' 'NCRSAL704' 'NCRSAN919' 'NCRSHE704' 'NCRSIC919'
#  'NCRSMF757' 'NCRSMI919' 'NCRSPN910' 'NCRVIR757' 'NCRWAK919' 'NCRWIN336'
#  'NCRWLM757' 'NCRYOR803' 'NEVCHU619' 'NEVCOR619' 'NEVELC619' 'NEVENC760'
#  'NEVESC760' 'NEVLAU702' 'NEVLMS619' 'NEVLVS702' 'NEVNAT619' 'NEVOCN760'
#  'NEVPOW619' 'NEVSDG619' 'NMCGDJ970' 'NMCPUE719' 'NMXABI915' 'NMXALB505'
#  'NMXAMA806' 'NMXDEL830' 'NMXEAG830' 'NMXELP915' 'NMXFLA520' 'NMXLAR956'
#  'NMXLCR505' 'NMXLSA505' 'NMXLUB806' 'NMXPLA806' 'NMXPRE520' 'NMXSAN505'
#  'NMXSAN915' 'NMXTER915' 'NMXYUM520' 'NNYALB518' 'NNYBUF716' 'NNYBUR914'
#  'NNYPOU914' 'NNYROC716' 'NNYSYR315' 'NNYUTI315' 'NOLBOG504' 'NOLKEN504'
#  'NOLPIC601' 'NOLPOH504' 'NORALX320' 'NORDUL218' 'NORFAR701' 'NORFER218'
#  'NORFRM218' 'NORMAN507' 'NOROWT507' 'NORRDW651' 'NORROC507' 'NORSTC320'
#  'NORZIM763' 'NSHCOL615' 'NSHNSH615' 'NSHSPR615' 'NVUGAR775' 'NVUREN775'
#  'NYCBRO917' 'NYCCIT914' 'NYCETT732' 'NYCFHD732' 'NYCJER201' 'NYCKPT732'
#  'NYCMAN917' 'NYCMTK914' 'NYCNAS516' 'NYCNEW201' 'NYCNEW732' 'NYCNEW908'
#  'NYCNEW973' 'NYCPAS973' 'NYCPLA908' 'NYCPLS609' 'NYCQUE917' 'NYCSUF516'
#  'NYCTMR732' 'NYCWHI914' 'NYCWOO732' 'OHHASH606' 'OHHATH740' 'OHHCAM740'
#  'OHHCHA304' 'OHHCHI740' 'OHHCLA304' 'OHHFAI304' 'OHHGAL740' 'OHHHUN304'
#  'OHHJAC740' 'OHHMOR304' 'OHHMTA740' 'OHHPAR304' 'OHHPOR740' 'OHHWAV740'
#  'OHHZAN740' 'OHIAKR330' 'OHIALL330' 'OHIASH419' 'OHIAUR330' 'OHIBCY419'
#  'OHIBER440' 'OHIBUT419' 'OHICAN330' 'OHICIN513' 'OHICIR740' 'OHICLB330'
#  'OHICLE216' 'OHICOL614' 'OHICOV606' 'OHIDAY937' 'OHIDEL740' 'OHIELY440'
#  'OHIHAR330' 'OHIKEN330' 'OHILAN740' 'OHILAW812' 'OHILEB513' 'OHILRN440'
#  'OHIMAN419' 'OHIMAR740' 'OHIMED330' 'OHIMID513' 'OHIMRY937' 'OHIMTV740'
#  'OHINCA937' 'OHINEW740' 'OHINOR419' 'OHIOBE440' 'OHIOXF513' 'OHIPIQ937'
#  'OHIPSV440' 'OHIRAV330' 'OHISAN419' 'OHISGF937' 'OHITRO937' 'OHITRT937'
#  'OHIWAR330' 'OHIWIL937' 'OHIWOO330' 'OHIXEN937' 'OHIYNG330' 'OKCARD580'
#  'OKCBAR918' 'OKCBEN501' 'OKCBTN501' 'OKCCAB501' 'OKCCHC405' 'OKCCON501'
#  'OKCEMP316' 'OKCEND580' 'OKCFAY501' 'OKCFTS501' 'OKCJUN785' 'OKCLAW580'
#  'OKCLRK501' 'OKCMAN785' 'OKCMCA918' 'OKCMCP316' 'OKCMUS918' 'OKCOKC405'
#  'OKCSAL785' 'OKCSTW405' 'OKCTUL918' 'OKCWIC940' 'OMAAMS515' 'OMACDR319'
#  'OMADES515' 'OMAGRN515' 'OMAIWC319' 'OMALNC402' 'OMANEW515' 'OMAOMA402'
#  'PHIALL484' 'PHIARD610' 'PHIAVD610' 'PHIBRI856' 'PHICAM302' 'PHICAP609'
#  'PHICHC215' 'PHICTR610' 'PHIDOV302' 'PHIELK443' 'PHIGEO302' 'PHIJEN215'
#  'PHILAN717' 'PHIMER609' 'PHIMID302' 'PHIMIL302' 'PHIMIV856' 'PHIMUL609'
#  'PHIPHI215' 'PHIPLS609' 'PHIRDN484' 'PHISAL856' 'PHISCR717' 'PHITRT609'
#  'PHIVIN609' 'PHIWIL302' 'PHIWLW609' 'PHXGLE623' 'PHXPHX602' 'PHXSCO480'
#  'PHXTUC520' 'PITBUT412' 'PITCAR412' 'PITCOR412' 'PITFOR412' 'PITGIB412'
#  'PITGRE412' 'PITHOM412' 'PITIND724' 'PITMNG412' 'PITMON412' 'PITNEW412'
#  'PITROC412' 'PITSOM814' 'PITUNT412' 'PITWAS412' 'PITWEI304' 'PITWHE304'
#  'SANAUS512' 'SANCOC254' 'SANCRP512' 'SANFRE830' 'SANGEO512' 'SANGIL830'
#  'SANKER830' 'SANKIL254' 'SANLAM512' 'SANMCA210' 'SANREF361' 'SANROM956'
#  'SANSAN210' 'SANSMC512' 'SANTEM254' 'SANWOO361' 'SDABRK605' 'SDASFL605'
#  'SDAWTR605' 'SEAABN253' 'SEAALB541' 'SEABEA503' 'SEABLG360' 'SEABLV425'
#  'SEABOI208' 'SEACDA208' 'SEACHE360' 'SEACOR541' 'SEADAL503' 'SEAEUG541'
#  'SEAEVE425' 'SEALEW208' 'SEALVW360' 'SEAMON503' 'SEAMTV360' 'SEAOKH360'
#  'SEAOLY360' 'SEAPOR503' 'SEASAL503' 'SEASEA206' 'SEASIL360' 'SEASPO509'
#  'SEATAC253' 'SEAVAN360' 'SEWGTP541' 'SEWKEN509' 'SEWKHF541' 'SEWMED541'
#  'SEWMLF541' 'SEWPAS509' 'SEWPEN541' 'SEWPRO509' 'SEWROS541' 'SEWSUN509'
#  'SEWWAL509' 'SEWYAK509' 'SFRCBL408' 'SFRCON925' 'SFRCRU831' 'SFRDAN925'
#  'SFRDSR925' 'SFRFAI707' 'SFRHAY510' 'SFROAK510' 'SFROAK925' 'SFRPAL650'
#  'SFRRCM510' 'SFRROC916' 'SFRSAC916' 'SFRSCL408' 'SFRSFR415' 'SFRSFS650'
#  'SFRSGS530' 'SFRSMO650' 'SFRSRO707' 'SFRVAC707' 'SFRWLC925' 'SFRWOO530'
#  'SFRWTV831' 'SFURED530' 'SFUSAC530' 'SHECAR717' 'SHECHA717' 'SHEEDI540'
#  'SHEFTR540' 'SHEHAG301' 'SHEHAR540' 'SHEMAR304' 'SHEMYE301' 'SHEWIN540'
#  'SHEYOR717' 'SLCKAY801' 'SLCOGD801' 'SLCPRK435' 'SLCPRO801' 'SLCSLC801'
#  'SLCTOO801' 'SLUSTG435' 'STLCHA636' 'STLCHE636' 'STLCMB573' 'STLCOL618'
#  'STLCPG573' 'STLCRD618' 'STLFUL573' 'STLHNB573' 'STLJEF573' 'STLJOP417'
#  'STLJOS816' 'STLOZA573' 'STLPIT316' 'STLPRB573' 'STLQUI217' 'STLROL573'
#  'STLSED660' 'STLSPR417' 'STLSTL314' 'VAHCHL804' 'VAHDAN804' 'VAHLYN804'
#  'VAHMTN540' 'VAHRAD540' 'VAHROA540' 'VAHSTA540' 'VAHWAY540']
# feature : ChildrenInHH
# encoded : ['No' 'Yes']
# feature : HandsetRefurbished
# encoded : ['No' 'Yes']
# feature : HandsetWebCapable
# encoded : ['No' 'Yes']
# feature : TruckOwner
# encoded : ['No' 'Yes']
# feature : RVOwner
# encoded : ['No' 'Yes']
# feature : Homeownership
# encoded : ['Known' 'Unknown']
# feature : BuysViaMailOrder
# encoded : ['No' 'Yes']
# feature : RespondsToMailOffers
# encoded : ['No' 'Yes']
# feature : OptOutMailings
# encoded : ['No' 'Yes']
# feature : NonUSTravel
# encoded : ['No' 'Yes']
# feature : OwnsComputer
# encoded : ['No' 'Yes']
# feature : HasCreditCard
# encoded : ['No' 'Yes']
# feature : NewCellphoneUser
# encoded : ['No' 'Yes']
# feature : NotNewCellphoneUser
# encoded : ['No' 'Yes']
# feature : OwnsMotorcycle
# encoded : ['No' 'Yes']
# feature : HandsetPrice
# encoded : ['10' '100' '130' '150' '180' '200' '240' '250' '30' '300' '40' '400'
#  '500' '60' '80' 'Unknown']
# feature : MadeCallToRetentionTeam
# encoded : ['No' 'Yes']
# feature : CreditRating
# encoded : ['1-Highest' '2-High' '3-Good' '4-Medium' '5-Low' '6-VeryLow' '7-Lowest']
# feature : PrizmCode
# encoded : ['Other' 'Rural' 'Suburban' 'Town']
# feature : Occupation
# encoded : ['Clerical' 'Crafts' 'Homemaker' 'Other' 'Professional' 'Retired' 'Self'
#  'Student']
# feature : MaritalStatus
# encoded : ['No' 'Unknown' 'Yes']

# %% [markdown]
# ## 3-3. Data Split

# %%
from sklearn.model_selection import train_test_split

X = data.drop(columns=['ServiceArea', 'Churn'])
y = data['Churn']

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    stratify=y,
    random_state=42
)

print(f"X_train shape : {X_train.shape}")
print(f"y_train shape : {y_train.shape}")
print(f"X_val shape : {X_val.shape}")
print(f"y_val : {y_val.shape}")
# Out:
# X_train shape : (37314, 56)
# y_train shape : (37314,)
# X_val shape : (12438, 56)
# y_val : (12438,)

# %% [markdown]
# # 4. Define Model, Train

# %%
from sklearn.ensemble import RandomForestClassifier

baseline = RandomForestClassifier()

baseline.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # 5. Validation Model

# %%
from sklearn.metrics import classification_report

y_pred = baseline.predict(X_val)

print(classification_report(y_true=y_val, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.98      0.83      8877
#            1       0.59      0.08      0.14      3561
#
#     accuracy                           0.72     12438
#    macro avg       0.66      0.53      0.49     12438
# weighted avg       0.69      0.72      0.63     12438
